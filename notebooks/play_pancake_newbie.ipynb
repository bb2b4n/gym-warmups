# %%
import gym
import gym_warmups
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import gym_warmups
env = gym.make('Pancakes-Newbie-v0')
env.reset()
for i in range(10000):
    v, r, c, _ = env.step(env.action_space.sample()) # take a random action
    print("Iteration %i reward is %i\n%s"%(i,r,env.render('ansi').getvalue()))
    if c:
        break;
plt.imshow(env.render('rgb_array'))
# Out:
# [2016-10-16 01:06:25,832] Making new env: Pancakes-Newbie-v0
# Iteration 0 reward is 4
#   ppppp
#     p
#    ppp
#  ppppppp
#
# Iteration 1 reward is 4
#   ppppp
#     p
#    ppp
#  ppppppp
#
# Iteration 2 reward is 2
#    ppp
#     p
#   ppppp
#  ppppppp
#
# Iteration 3 reward is 8
#  ppppppp
#   ppppp
#     p
#    ppp
#
# Iteration 4 reward is 8
#  ppppppp
#   ppppp
#     p
#    ppp
#
# Iteration 5 reward is 8
#  ppppppp
#   ppppp
#     p
#    ppp
#
# Iteration 6 reward is 8
#  ppppppp
#   ppppp
#     p
#    ppp
#
# Iteration 7 reward is 8
#  ppppppp
#   ppppp
#     p
#    ppp
#
# Iteration 8 reward is 4
#     p
#   ppppp
#  ppppppp
#    ppp
#
# Iteration 9 reward is 4
#     p
#   ppppp
#  ppppppp
#    ppp
#
# Iteration 10 reward is 8
#  ppppppp
#   ppppp
#     p
#    ppp
#
# Iteration 11 reward is 8
#   ppppp
#  ppppppp
#     p
#    ppp
#
# Iteration 12 reward is 4
#    ppp
#     p
#  ppppppp
#   ppppp
#
# Iteration 13 reward is 4
#    ppp
#     p
#  ppppppp
#   ppppp
#
# ...
